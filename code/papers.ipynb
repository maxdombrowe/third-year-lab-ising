# %% [markdown]
# # Ads / CFT correspondence for use in Black Hole Holography
#
# Local bulk operators in AdS/CFT correspondence: A holographic description of the black hole interior, Alex Hamilton,1,* Daniel Kabat,1,† Gilad Lifschytz,2,‡ and David A. Lowe3
# https://journals.aps.org/prd/pdf/10.1103/PhysRevD.75.106001
#
# Simple Bulk Reconstruction in AdS/CFT Correspondence, Seiji Terashima
# https://arxiv.org/pdf/2104.11743
#
# The Ising model as a window on quantum gravity with matter, Romuald A. Janik
# https://arxiv.org/html/2502.19015v3#S5

# %% [markdown]
# # Quantum CFT Ising Chains
